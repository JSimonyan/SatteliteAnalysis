# %% [markdown]
# # Goal and Outcomes Revisited:
# Initially, we had not been very explicit with our goals and expectations. To alleviate this we have decided to deviate somewhat from our initial project proposal. The purpose and goal of our analysis is to find correlations between changes in population and changes in environment through the use of satellite images and other feature sets that correlate to the aforementioned region. Ideally what we expect to find by applying pixel by pixel hue analysis to the images are changes in infrastructure and region density that would contribute to a change in the region's average color. We can then find a correlation between changes in the color saturation from the images and the changes happening within the chosen feature set. Not identifying any expected changes would not be a failure of our analysis because factors such as population density in regions and the differences between the selected location all may play a part in our observations. Those differences may also give some other unintended insight about the potential factors affecting our study.

# %% [markdown]
# # Data:
# While our initial focus was posited on the satellite analysis, we have decided to shift towards comparisons with another data set. More specifically looking at cities in the United States and changes in their population. We have two sources for this data; one is from  https://simplemaps.com/data/us-cities and contains population location and more features. The other is from https://www.downloadexcelfiles.com/us_en/download-excel-file-list-state-capitals-united-states, and contains state capitals along with state and capital statistics. The population values for cities are updated as of Jan. 31 2021 and will serve as our primary response variable.
#
# The satellite images obtained from the NASA Earth API contain visual information about urban features and this is conveyed in its hue saturation. The red, blue, and green values within the picture are objects and their average color values as seen from space. These images are pre-processsed by NASA to mitigate effects of the time of day a photo is taken. If an area has more of a certain type of object in a region we can expect to see that represented, if there are enough of the objects, by an increase of that object's color hue in that image. So, we have to queried photos from U.S. capitals at from two different years to test our hypothesis that changes in environment and the color hues therein correlate with the population of a city at one point in time. This will be modeled with a classification method (perhaps kNN), trained and tested with subsets of the image and population data. With additional non-image features, we will create a multi-linear regression to predict the population of capitals and all U.S. cities and compare it to the efficacy of our image analysis.

# %%
#load csv of city coordinates
#loaded dataset parsed by wether row is capital or not
import pandas as pd

us_cities = pd.read_csv("us_cities_v2.csv")
us_cities.loc[us_cities['capital']]
# Out:
#                 city state_id                 state                county  \
# 7            Atlanta       GA               Georgia                Fulton
# 8         Washington       DC  District of Columbia  District of Columbia
# 9             Boston       MA         Massachusetts               Suffolk
# 10           Phoenix       AZ               Arizona              Maricopa
# 17            Denver       CO              Colorado                Denver
# 26        Sacramento       CA            California            Sacramento
# 31            Austin       TX                 Texas                Travis
# 35      Indianapolis       IN               Indiana                Marion
# 36          Columbus       OH                  Ohio              Franklin
# 41        Providence       RI          Rhode Island            Providence
# 43    Salt Lake City       UT                  Utah             Salt Lake
# 44         Nashville       TN             Tennessee              Davidson
# 45          Richmond       VA              Virginia              Richmond
# 47           Raleigh       NC        North Carolina                  Wake
# 50     Oklahoma City       OK              Oklahoma              Oklahoma
# 54          Hartford       CT           Connecticut              Hartford
# 58          Honolulu       HI                Hawaii              Honolulu
# 69           Concord       CA            California          Contra Costa
# 71        Charleston       SC        South Carolina            Charleston
# 72       Springfield       MA         Massachusetts               Hampden
# 75            Albany       NY              New York                Albany
# 79       Baton Rouge       LA             Louisiana      East Baton Rouge
# 82          Columbia       SC        South Carolina              Richland
# 92        Des Moines       IA                  Iowa                  Polk
# 96           Madison       WI             Wisconsin                  Dane
# 98        Harrisburg       PA          Pennsylvania               Dauphin
# 99       Little Rock       AR              Arkansas               Pulaski
# 113          Augusta       GA               Georgia              Richmond
# 114            Boise       ID                 Idaho                   Ada
# 130          Jackson       MS           Mississippi                 Hinds
# 132          Lansing       MI              Michigan                Ingham
# 142       Saint Paul       MN             Minnesota                Ramsey
# 145          Trenton       NJ            New Jersey                Mercer
# 146          Lincoln       NE              Nebraska             Lancaster
# 164            Salem       OR                Oregon                Marion
# 173      Tallahassee       FL               Florida                  Leon
# 176       Montgomery       AL               Alabama            Montgomery
# 215          Olympia       WA            Washington              Thurston
# 288           Topeka       KS                Kansas               Shawnee
# 362            Dover       DE              Delaware                  Kent
# 387         Santa Fe       NM            New Mexico              Santa Fe
# 446         Bismarck       ND          North Dakota              Burleigh
# 552         Cheyenne       WY               Wyoming               Laramie
# 790      Carson City       NV                Nevada           Carson City
# 801   Jefferson City       MO              Missouri                  Cole
# 884           Helena       MT               Montana       Lewis and Clark
# 1145       Annapolis       MD              Maryland          Anne Arundel
# 1161       Frankfort       KY              Kentucky              Franklin
# 1379          Juneau       AK                Alaska                Juneau
# 2682          Pierre       SD          South Dakota                Hughes
# 4312      Montpelier       VT               Vermont            Washington
#
#           lat      long  population  density   source  military  incorporated  \
# 7     33.7627  -84.4224     5449398     1441  polygon     False          True
# 8     38.9047  -77.0163     5379184     4457  polygon     False          True
# 9     42.3188  -71.0846     4688346     5532  polygon     False          True
# 10    33.5722 -112.0891     4219697     1253  polygon     False          True
# 17    39.7621 -104.8759     2876625     1831  polygon     False          True
# 26    38.5667 -121.4683     1898019     2029  polygon     False          True
# 31    30.3004  -97.7522     1687311     1181  polygon     False          True
# 35    39.7771  -86.1458     1588961      935  polygon     False          True
# 36    39.9862  -82.9850     1562009     1582  polygon     False          True
# 41    41.8230  -71.4187     1203230     3773  polygon     False          True
# 43    40.7777 -111.9306     1098526      699  polygon     False          True
# 44    36.1715  -86.7843     1081903      544  polygon     False          True
# 45    37.5295  -77.4756     1075798     1484  polygon     False          True
# 47    35.8325  -78.6435     1038738     1254  polygon     False          True
# 50    35.4676  -97.5136      972943      417  polygon     False          True
# 54    41.7661  -72.6834      905152     2712  polygon     False          True
# 58    21.3294 -157.8460      820987     2200  polygon     False          True
# 69    37.9722 -122.0016      652308     1633  polygon     False          True
# 71    32.8153  -79.9628      628377      480  polygon     False          True
# 72    42.1155  -72.5395      623401     1860  polygon     False          True
# 75    42.6664  -73.7987      586383     1740  polygon     False          True
# 79    30.4418  -91.1310      570308      983  polygon     False          True
# 82    34.0376  -80.9037      560041      373  polygon     False          True
# 92    41.5725  -93.6105      473957      938  polygon     False          True
# 96    43.0826  -89.3931      447245     1263  polygon     False          True
# 98    40.2752  -76.8843      442289     2343  polygon     False          True
# 99    34.7256  -92.3576      439815      634  polygon     False          True
# 113   33.3645  -82.0708      390809      252  polygon     False          True
# 114   43.6007 -116.2312      389280     1056  polygon     False          True
# 130   32.3163  -90.2124      325350      558  polygon     False          True
# 132   42.7142  -84.5601      324286     1164  polygon     False          True
# 142   44.9477  -93.1040      308096     2288  polygon     False          True
# 145   40.2236  -74.7641      290716     4238  polygon     False          True
# 146   40.8090  -96.6788      289490     1160  polygon     False          True
# 164   44.9231 -123.0246      266804     1382  polygon     False          True
# 173   30.4551  -84.2526      257601      747  polygon     False          True
# 176   32.3473  -86.2666      254634      479  polygon     False          True
# 215   47.0417 -122.8959      200915     1119  polygon     False          True
# 288   39.0346  -95.6955      147458      787  polygon     False          True
# 362   39.1610  -75.5203      117282      622  polygon     False          True
# 387   35.6619 -105.9819      111269      625  polygon     False          True
# 446   46.8144 -100.7694       98345      827  polygon     False          True
# 552   41.1351 -104.7900       79484      771  polygon     False          True
# 790   39.1512 -119.7474       58756      149  polygon     False          True
# 801   38.5676  -92.1759       58025      457  polygon     False          True
# 884   46.5965 -112.0202       52936      760  polygon     False          True
# 1145  38.9706  -76.5047       39223     2100  polygon     False          True
# 1161  38.1924  -84.8643       38852      725  polygon     False          True
# 1379  58.4546 -134.1739       31974        4  polygon     False          True
# 2682  44.3748 -100.3205       14659      410  polygon     False          True
# 4312  44.2658  -72.5717        7372      283  polygon     False          True
#
#       capital                      timezone  ranking  zips
# 7        True              America/New_York        1    56
# 8        True              America/New_York        1   292
# 9        True              America/New_York        1    53
# 10       True               America/Phoenix        1    82
# 17       True                America/Denver        1    54
# 26       True           America/Los_Angeles        1    86
# 31       True               America/Chicago        1    71
# 35       True  America/Indiana/Indianapolis        1    53
# 36       True              America/New_York        1    54
# 41       True              America/New_York        1    12
# 43       True                America/Denver        1    32
# 44       True               America/Chicago        1    50
# 45       True              America/New_York        1    32
# 47       True              America/New_York        1    37
# 50       True               America/Chicago        2    77
# 54       True              America/New_York        2    32
# 58       True              Pacific/Honolulu        2    41
# 69       True           America/Los_Angeles        2     7
# 71       True              America/New_York        2    15
# 72       True              America/New_York        2    20
# 75       True              America/New_York        2    38
# 79       True               America/Chicago        2    33
# 82       True              America/New_York        2    24
# 92       True               America/Chicago        2    44
# 96       True               America/Chicago        2    29
# 98       True              America/New_York        2    18
# 99       True               America/Chicago        2    22
# 113      True              America/New_York        2    15
# 114      True                 America/Boise        2    22
# 130      True               America/Chicago        2    30
# 132      True               America/Detroit        2    18
# 142      True               America/Chicago        2    23
# 145      True              America/New_York        2    17
# 146      True               America/Chicago        2    22
# 164      True           America/Los_Angeles        2    10
# 173      True              America/New_York        2    16
# 176      True               America/Chicago        2    31
# 215      True           America/Los_Angeles        2     7
# 288      True               America/Chicago        2    24
# 362      True              America/New_York        2     5
# 387      True                America/Denver        2     6
# 446      True               America/Chicago        2     5
# 552      True                America/Denver        2     5
# 790      True           America/Los_Angeles        2     9
# 801      True               America/Chicago        2    11
# 884      True                America/Denver        2     6
# 1145     True              America/New_York        2     4
# 1161     True              America/New_York        2     8
# 1379     True                America/Juneau        2     8
# 2682     True               America/Chicago        2     1
# 4312     True              America/New_York        2     5

# %% [markdown]
# # Data Processing:
# Processing and normalizing the satellite images were have big factors as to why we changed our project's scope. As we began to process the returned image queries, we found that there was a lot more cloud obfuscation than we had expected. If the images contained clouds, the clouds would dominate the photo with a mostly pure white saturation. So we came up with a method to parse out the images we found that are too cloudy. We did this by analysing the distribution of colors in the image; if white exceeded the average red, green, or blue values by some amount, the image would be filtered out and the next month would be queried.
#
# We also had to consider that the API returns an image closest to the queried date, causing ambiguity and possible image duplicates. Significant changes in population, and thereby topography, can potentially take months and years to happen. So our rate of topographical changes will be in terms of years, giving lending to less image ambiguity.
#
# To minimize time taken to collect the data and write queries, we chose to implement a script to dynamically make calls to the NASA Earth API. The calls were being made by processing our dataset of cities and coordinates. The program then pushed those coordinates to the API and wrote the responses to individual files within our 'images' folder. We wrote a script that would vet out cloudy images and re-query clearer images. We saved two images for each capital at different years to a folder so we could more easily manipulate them without worrying about hitting the query limit for NASA's API. We decided to limit the images to 32 x 32, although we will likely reduce these even more for processing. This way we could more easily normalize and analyze the data. By also limiting ourselves to only U.S. capitals, we can clearly define the scope of our queries and analysis. Choosing to only select two images per capital will allow to see an initial condition and final condition to extract a rate of change in average color, with the implicit assumption that the change will be close to linear. With this rate of change quantified, we can apply it in analysis.

# %%
import os, cv2, requests, base64, imageio
from PIL import Image
from io import BytesIO
import seaborn as sn
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

us_cities = pd.read_csv("us_cities_v2.csv")

# %%
#this is the script to filter cloudy images 
#The full code can be found the collector.ipynb within the contained folder

def next_mo(date):
    mo = '0' + str(int(date[5:7]) + 1)
    if len(mo) > 2:
        mo = mo[1:]
    date = date[:5] + mo + date[7:]
    return date

def is_cloudy(img):
    #Takes Image object, returns bool if it meets 'cloudy' criteria
    k = 75 #Threshold coeff.
    
    hist = img.histogram()
    Rm = np.mean(hist[:256])
    Gm = np.mean(hist[256:512])
    Bm = np.mean(hist[512:])
    W = [hist[255], hist[511], hist[-1]]
    
    if W[0] > k*Rm or W[1] > k*Gm or W[2] > k*Bm:
        return True
    else:
        return False

#Load lat and long csv
us_cities = pd.read_csv("us_cities_v2.csv")
us_cities

capitals = us_cities.loc[us_cities['capital']]
capitals = capitals.reset_index(drop=True)

site = "https://api.nasa.gov/planetary/earth/imagery?"
key1 = "II3XUxmGYfFKmyapNeXjrH3Os3ILNhQScjW6bbMT"
key2 = "07b9v4Pg29fysvhDf1q6x0UyOaGZxXIfryIv9PKO"

dates = ['2016-05-01', '2019-05-01']

counter = 0
for date in dates:
    for i, city in capitals.iterrows():
        date_ = date
        
        # Query API for capital image
        url = site + "lon=" + str(city['long']) + "&lat=" + str(city['lat']) + \
                  "&dim=.1&date=" + date + "&api_key=" + key1
        
        response = requests.get(url)
        print("Ok?",response.ok,'i =',i)
            
        if response.ok:
            img = Image.open(BytesIO(response.content))
            cloudy = is_cloudy(img)
            print(cloudy)
                
            attempts = 0
            while cloudy and attempts <= 4:
                #NOTE - Selects nearest date
                date = next_mo(date)
                    
                url = site + "lon=" + str(city['long']) + "&lat=" + str(city['lat']) + \
                    "&dim=.1&date=" + date + "&api_key=" + key1
                response = requests.get(url)
                    
                img = Image.open(BytesIO(response.content))
                    
                cloudy = is_cloudy(img)
                attempts += 1
                    
            if response.ok:
                img = img.resize((32,32))
                    
                name = '_' + city['city'].replace(' ','_') + '_' + date.replace('-','_') + '.png'
                #saves images to folder with noramalized name 
                #img.save(name)
                date = date_
                counter += 1
                    
            if attempts > 4:
                print(city['city'], date)
                date = date_
print(counter)

# %% [markdown]
# # Ethical Considerations:
# Our original perspective on ethical considerations has not changed drastically. We are definitely avoiding making any claims about cities in terms of population classifications and how it relates socioeconomically or what analyzed values correlate to in terms of quality or perceived superiority or inferiority. The only claims we are trying to make are in relation to population and changes in visual features as observed from our data source.
# An ethical consideration that we did not touch on in our project proposal was our sources. The resources we utilize for our project are allowed within the license and terms of the dataset. This is only based on certain conditions, such as using the data for academic purposes. The dataset is ethical to use as long as we properly source where we collected it from. This can be seen by reading the uses and use clauses as defined in the data license.
# Sources:
# https://simplemaps.com/data/us-cities.csv
# https://www.downloadexcelfiles.com/us_en/download-excel-file-list-state-capitals-united-states

# %% [markdown]
# # Exploratory Analysis and Approach:
# Shifting our focus to population changes we can look at the population as our response variable. We can cross reference that variable with our processed image data to test if our hypothesis works and if there is a viable correlation between the two. The way we are analyzing our image set is by mapping the red, blue, green color values to a histogram. The intensity of the histogram gives a good visual tool to understand the data being explored. Variances in color concentrations can indicate a variety of things, but we are trying to isolate its specific relationship with the analyzed regions' population. To do this we must compare found values to expected values based on the change in the location over the given period. Establishing a control will allow us to specify what changes we can expect with a city's growth due to population increase. We expect to find a linear change in the color values based on the changes in topography due to population increase. Something to consider is density of the new population and whether they tend to migrate towards dense populace centers or expand out on the cities outlying regions. Even if population growth is only increasing in density we should still expect so see some changes in color saturation for that growing region.

# %%
#show how we can proccess images as histograms
#Takes Image object, returns bool if it meets 'cloudy' criteria
#side by side of same location but different dates plotted as heat map
k = 75 #Threshold coeff.

img = Image.open('images/_Albany_2017_03_01.png')
img2 = Image.open('images/_Albany_2020_05_01.png')

hist = img.histogram()
hist2 =img2.histogram()

#iterate through img histogram to find rgb values
Rm = hist[0:256]
Gm = hist[256:512]
Bm = hist[512:768]

Rm2 = hist2[0:256]
Gm2 = hist2[256:512]
Bm2 = hist2[512:768]


def Red(R): 
    return '#%02x%02x%02x'%(R,0,0)
def Green(G): 
    return '#%02x%02x%02x'%(0,G,0)
def Blue(B):
    return '#%02x%02x%02x'%(0,0,B)

for i in range(0, 256):
    plt.bar(i, Rm[i], color = Red(i), alpha = .5)
    plt.figure(1) # plot red
for i in range(0, 256):
    plt.bar(i, Gm[i], color = Green(i), alpha = .5)
    plt.figure(2) # plot green
for i in range(0, 256):
    plt.bar(i, Bm[i], color = Blue(i), alpha = .5)
    plt.figure(3) #plot blue
plt.show()

for i in range(0, 256):
    plt.bar(i, Rm2[i], color = Red(i), alpha = .5)
    plt.figure(1) # plot red
for i in range(0, 256):
    plt.bar(i, Gm2[i], color = Green(i), alpha = .5)
    plt.figure(2) # plot green
for i in range(0, 256):
    plt.bar(i, Bm2[i], color = Blue(i), alpha = .5)
    plt.figure(3) #plot blue
plt.show()

# %%
sn.pairplot(us_cities)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# # Analysis Methodology
# We plan to approach the population (and or population density) of each city and capital, respectively, as a response variable that is predicted by a multi-linear regression model and topographical classification model, respectively. The final multi-linear regression will consider some combination of the features listed in the dataframe above, and it is up to us to tune the model and identify how each of the features relate to population.
#
# We must consider our approach to topographical classification carefully, since we expect different outcomes based on described attributes. Changes in color for one region may differ from another. This can be due to different geographical features or the natural environment of the specified area. It’s important to understand and anticipate certain analytical failings and be able to understand the underlying cause of them. The results may seem to indicate one thing, but there may be others unforeseen factors impacting our analysis. Being thorough in our interpretation of results is important to testing the accuracy of our claims. As such analytical our methodologies implement those restraints in mind to keep our results giving us the appropriate answer based on the featureset.
#
# We hypothesize that a population, or its density, will correlate to some rate of change in an set of images' features. We will use one of the methods covered in class to model this correlation and test its significance and compare the accuracy of the model to a multi-linear regression. From the pair plot above, we already see that the number of ZIP codes city has correlates significantly with population.
